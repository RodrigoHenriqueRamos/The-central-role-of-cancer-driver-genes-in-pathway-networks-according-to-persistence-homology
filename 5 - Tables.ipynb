# %%
import warnings
warnings.filterwarnings('ignore')
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import networkx as nx
import pickle
import gudhi as gd

# %%
class PathwayClass:
    def __init__(self, name,idPathway,geneSet,networkWithCCs,networkLCC,drivers):
        self.name = name
        self.id = idPathway
        self.geneSet = geneSet
        self.networkCCs = networkWithCCs
        self.networkLCC = networkLCC
        self.drivers = drivers
        self.topologicalFeaturesLCC = None
        self.layout_LCC_kamada_kawai= None
        self.layout_CCs_spring = None
        self.father = None
        self.children = {}

class PathwaysWrapper:
    def __init__(self, pathwaysObjsIds,pathwaysObjsNames,pathwaysNamesForest,listOfObjects):
        self.pathwaysIds=pathwaysObjsIds
        self.pathwaysNames=pathwaysObjsNames
        self.pathwaysNamesForest=superPathwaysNamesForest
        self.listOfRoots=listOfRoots
        
file = open("../../Super Pathways - Hierarquia/1 - Output/SuperPathwaysAndPathways.pkl", "rb")
pathwaysWrapper = pickle.load(file)

# %% [markdown]
# # LookUp Tables

# %%
names={
    'DNA':'DNA Repair',
    'CHR':'Chromatin organization',
    'PCD':'Programmed Cell Death'
}

paths={
    'DNA':'/matriz_reactome_missense_repair.csv',
    'CHR':'/matriz_reactome_missense_chromatin.csv',
    'PCD':'/matriz_reactome_missense_death.csv'
}
cancerType={
    'Cabeça':'Head and Neck',
    'Estomago':'Stomach',
    'Mama':'Breast',
    'Pele':'Skin',
    'Pulmao':'Lung',
    'Urothelial':'Bladder'
}

# %% [markdown]
# # Networks Size

# %%
networks={}
resumeNodes={}
resumeEdges={}
for name in ['CHR','DNA','PCD']:
    resumeNodes[name]={}
    resumeEdges[name]={}
    networks[name]=pathwaysWrapper.pathwaysNames[names[name]].networkLCC
    resumeNodes[name]['Original']=networks[name].number_of_nodes()
    resumeEdges[name]['Original']=networks[name].number_of_edges()
    
    for ct in cancerType:
        geneSet=set(pd.read_csv("1 input/"+ct+paths[name],index_col=[0]).index)
        G=networks[name].copy()
        ct=cancerType[ct]
        G.name=ct
        networks[ct]=nx.subgraph(G,geneSet)
        resumeNodes[name][ct]=networks[ct].number_of_nodes()
        resumeEdges[name][ct]=networks[ct].number_of_edges()

# %%
percentuals={}
for sp in resumeNodes:
    percentuals[sp]=[]
    for net in resumeNodes[sp]:
        if net != 'Original':
            perc = int(100*resumeNodes[sp][net]/resumeNodes[sp]['Original'])
            resumeNodes[sp][net]=str(resumeNodes[sp][net])+' ('+str(perc)+'%)'
            percentuals[sp].append(perc)
display(pd.DataFrame(resumeNodes).T)
print('Média Percentual')
[(name, round(np.mean(values))) for name,values in percentuals.items()]
# Out:
#     Original Head and Neck    Stomach     Breast       Skin       Lung  \
# CHR      221     160 (72%)  148 (66%)  151 (68%)  175 (79%)  166 (75%)
# DNA      300     209 (69%)  191 (63%)  210 (70%)  251 (83%)  238 (79%)
# PCD      206     152 (73%)  137 (66%)  132 (64%)  186 (90%)  169 (82%)
#
#        Bladder
# CHR  165 (74%)
# DNA  242 (80%)
# PCD  174 (84%)
# Média Percentual
# [('CHR', 72), ('DNA', 74), ('PCD', 76)]

# %%
percentuals={}
for sp in resumeEdges:
    percentuals[sp]=[]
    for net in resumeEdges[sp]:
        if net != 'Original':
            perc = int(100*resumeEdges[sp][net]/resumeEdges[sp]['Original'])
            resumeEdges[sp][net]=str(resumeEdges[sp][net])+' ('+str(perc)+'%)'
            percentuals[sp].append(perc)
display(pd.DataFrame(resumeEdges).T)
print('Média Percentual')
[(name,round(np.mean(values))) for name,values in percentuals.items()]
# Out:
#     Original Head and Neck     Stomach      Breast        Skin        Lung  \
# CHR     2301    1279 (55%)  1097 (47%)  1099 (47%)  1472 (63%)  1267 (55%)
# DNA     6959    3712 (53%)  3029 (43%)  3827 (54%)  5326 (76%)  4875 (70%)
# PCD     2635    1550 (58%)  1209 (45%)  1133 (42%)  2256 (85%)  1754 (66%)
#
#         Bladder
# CHR  1338 (58%)
# DNA  4954 (71%)
# PCD  2009 (76%)
# Média Percentual
# [('CHR', 54), ('DNA', 61), ('PCD', 62)]

# %% [markdown]
# ## Driver per Networks

# %%
intoGen=set(pd.read_csv('99 input/intogen.tsv',sep='\t')['SYMBOL'])
ncg_canonical=set(pd.read_csv('99 input/ncg_canonical.txt',header=None)[0])
driverUnion = intoGen.union(ncg_canonical)
len(intoGen),len(ncg_canonical),len(driverUnion)
# Out:
# (568, 591, 787)

# %%
networks={}
resumeNodes={}
for name in ['CHR','DNA','PCD']:
    resumeNodes[name]={}
    networks[name]=pathwaysWrapper.pathwaysNames[names[name]].networkLCC
    resumeNodes[name]['Original']=len(set(networks[name].nodes())&driverUnion)
    
    for ct in cancerType:
        geneSet=set(pd.read_csv("1 input/"+ct+paths[name],index_col=[0]).index)
        G=networks[name].copy()
        ct=cancerType[ct]
        G.name=ct
        networks[ct]=nx.subgraph(G,geneSet)
        resumeNodes[name][ct]=len(set(networks[ct].nodes())&driverUnion)
        
        
percentuals={}
for sp in resumeNodes:
    percentuals[sp]=[]
    for net in resumeNodes[sp]:
        if net != 'Original':
            perc = int(100*resumeNodes[sp][net]/resumeNodes[sp]['Original'])
            resumeNodes[sp][net]=str(resumeNodes[sp][net])+' ('+str(perc)+'%)'
            percentuals[sp].append(perc)
display(pd.DataFrame(resumeNodes).T)
print('Média Percentual')
[(name, round(np.mean(values))) for name,values in percentuals.items()]
# Out:
#     Original Head and Neck   Stomach    Breast       Skin      Lung   Bladder
# CHR       45      42 (93%)  40 (88%)  43 (95%)   43 (95%)  42 (93%)  43 (95%)
# DNA       46      41 (89%)  42 (91%)  43 (93%)   44 (95%)  44 (95%)  44 (95%)
# PCD       26      24 (92%)  24 (92%)  22 (84%)  26 (100%)  25 (96%)  24 (92%)
# Média Percentual
# [('CHR', 93), ('DNA', 93), ('PCD', 93)]

# %% [markdown]
# ## REPORT

# %%
def resume(dimension,SP):
    with open('2 output/'+SP+'/barCodes_original.pkl',mode='rb') as f:
        barCodesOriginal=pickle.load(f)
    
    with open('2 output/'+SP+'/barCodes_WithOutDrivers.pkl',mode='rb') as f:
        barCodesWithOutDrivers=pickle.load(f)

    with open('2 output/'+SP+'/barCodes_WithRandom.pkl',mode='rb') as f:
        barCodesWithRandom=pickle.load(f)
    
    randomValues={}    
    names=[SP,'Urothelial','Cabeça','Mama','Pulmao','Pele','Estomago']
    for name in names:
        randomValues[name]=[]
        #9 is the number of networks = 6 Cancer + 1 
        randomRemovals=int(len(barCodesWithRandom.keys())/7)

        for i in range(1,randomRemovals+1):
            randomValues[name].append(len([dim for dim,liveTime in barCodesWithRandom[name+' - '+str(i)] if dim==dimension]))

    resume={}
    for name in names:
        resume[name]={}
        resume[name]['Original']   =len([dim for dim,liveTime in barCodesOriginal[name] if dim==dimension])
        resume[name]['Driver']     =len([dim for dim,liveTime in barCodesWithOutDrivers[name] if dim==dimension])
        resume[name]['Random Mean']=round(np.mean([dim for dim in randomValues[name]]),2)
        resume[name]['Random Median'] =round(np.median([dim for dim in randomValues[name]]),2)
        resume[name]['Random Std'] =round(np.std([dim for dim in randomValues[name]]),2)
        resume[name]['Random Min'] =round(np.min([dim for dim in randomValues[name]]),2)
        resume[name]['Random Max'] =round(np.max([dim for dim in randomValues[name]]),2)

    return pd.DataFrame(resume).T.rename(index=cancerType).astype({"Original": int, "Driver": int, 'Random Median': int, "Random Min": int, "Random Max": int})

# %% [markdown]
# #### Dimension 0

# %%
resumeTables={}
for sp in ['CHR','DNA','PCD']:
    resumeTables[sp]={}
    print('\n\n--------',sp,'\n')
    for dim in [0,1,2]:
        resumeTables[sp][dim]=resume(dim,sp)
        print('\nDimension',dim)
        display(resume(dim,sp))
# Out:
# -------- CHR
#
#
# Dimension 0
#                Original  Driver  Random Mean  Random Median  Random Std  \
# CHR                 221     171       173.73            174        2.38
# Bladder             165     111       116.13            117        2.70
# Head and Neck       160     105       113.27            113        2.08
# Breast              151      99       103.03            104        2.58
# Lung                166     112       118.63            119        2.33
# Skin                175     120       127.30            128        2.18
# Stomach             148      95       102.70            102        2.21
#
#                Random Min  Random Max
# CHR                   164         176
# Bladder               109         122
# Head and Neck         108         118
# Breast                 98         107
# Lung                  113         124
# Skin                  122         132
# Stomach                96         107
# Dimension 1
#                Original  Driver  Random Mean  Random Median  Random Std  \
# CHR                  18      13        15.57             16        2.68
# Bladder              17      17        11.60             11        2.91
# Head and Neck        15      17         9.77             10        2.80
# Breast               19      15        13.43             13        3.04
# Lung                 19      16        14.23             14        3.89
# Skin                 19      19        13.23             13        2.89
# Stomach              12      17         9.00             10        2.14
#
#                Random Min  Random Max
# CHR                    11          21
# Bladder                 7          17
# Head and Neck           5          16
# Breast                  8          21
# Lung                    8          28
# Skin                    9          21
# Stomach                 4          12
# Dimension 2
#                Original  Driver  Random Mean  Random Median  Random Std  \
# CHR                   4       1         2.27              2        1.18
# Bladder               3       0         1.10              1        0.79
# Head and Neck         2       0         1.10              1        0.87
# Breast                1       0         0.47              0        0.62
# Lung                  2       0         0.60              0        0.66
# Skin                  3       0         1.17              1        0.93
# Stomach               1       0         0.37              0        0.48
#
#                Random Min  Random Max
# CHR                     0           4
# Bladder                 0           3
# Head and Neck           0           3
# Breast                  0           2
# Lung                    0           2
# Skin                    0           3
# Stomach                 0           1
# -------- DNA
#
#
# Dimension 0
#                Original  Driver  Random Mean  Random Median  Random Std  \
# DNA                 300     254        252.2            252        1.60
# Bladder             242     197        197.5            198        0.67
# Head and Neck       209     167        167.1            167        0.94
# Breast              210     167        166.7            167        0.64
# Lung                238     193        193.2            193        0.40
# Skin                251     207        206.5            206        0.50
# Stomach             191     146        147.9            148        0.83
#
#                Random Min  Random Max
# DNA                   250         254
# Bladder               196         198
# Head and Neck         165         168
# Breast                165         167
# Lung                  193         194
# Skin                  206         207
# Stomach               146         149
# Dimension 1
#                Original  Driver  Random Mean  Random Median  Random Std  \
# DNA                  19       9         15.8             16        2.36
# Bladder              16       8         13.5             13        1.80
# Head and Neck        13       9          9.1              9        1.76
# Breast               16       9         11.5             12        2.06
# Lung                 14       8         10.7             11        1.68
# Skin                 16       8         12.2             12        0.98
# Stomach               9       8          6.9              7        1.30
#
#                Random Min  Random Max
# DNA                    13          20
# Bladder                10          16
# Head and Neck           7          13
# Breast                  8          14
# Lung                    8          14
# Skin                   11          14
# Stomach                 4           9
# Dimension 2
#                Original  Driver  Random Mean  Random Median  Random Std  \
# DNA                   7       3          5.2              5        1.47
# Bladder               8       4          5.6              5        1.36
# Head and Neck         4       1          3.7              3        1.00
# Breast                2       0          2.0              2        0.77
# Lung                  6       2          4.5              5        1.12
# Skin                  6       1          4.2              4        0.87
# Stomach               4       1          3.1              3        1.04
#
#                Random Min  Random Max
# DNA                     2           7
# Bladder                 4           8
# Head and Neck           2           5
# Breast                  1           3
# Lung                    3           6
# Skin                    3           5
# Stomach                 1           5
# -------- PCD
#
#
# Dimension 0
#                Original  Driver  Random Mean  Random Median  Random Std  \
# PCD                 206     165       179.80            180        0.48
# Bladder             174     138       149.87            150        0.34
# Head and Neck       152     116       127.60            128        0.55
# Breast              132      98       109.90            110        0.30
# Lung                169     129       143.73            144        0.51
# Skin                186     147       159.67            160        0.54
# Stomach             137     102       110.13            111        2.00
#
#                Random Min  Random Max
# PCD                   178         180
# Bladder               149         150
# Head and Neck         126         128
# Breast                109         110
# Lung                  142         144
# Skin                  158         160
# Stomach               106         112
# Dimension 1
#                Original  Driver  Random Mean  Random Median  Random Std  \
# PCD                  27      41        23.57             23        2.29
# Bladder              24      34        19.43             19        2.56
# Head and Neck        20      28        15.27             15        2.02
# Breast               15      21        11.67             12        1.85
# Lung                 22      33        17.17             17        2.54
# Skin                 24      34        20.03             20        2.50
# Stomach              28      24        20.00             20        3.27
#
#                Random Min  Random Max
# PCD                    18          28
# Bladder                13          23
# Head and Neck          10          19
# Breast                  8          15
# Lung                   12          23
# Skin                   15          24
# Stomach                12          27
# Dimension 2
#                Original  Driver  Random Mean  Random Median  Random Std  \
# PCD                  11       0         9.83             10        2.02
# Bladder              11       0         9.53              9        2.19
# Head and Neck        13       0        10.23             10        1.87
# Breast                8       0         6.33              6        2.04
# Lung                  8       0         6.67              7        1.60
# Skin                 10       0         9.37              9        2.02
# Stomach               7       0         5.27              5        1.57
#
#                Random Min  Random Max
# PCD                     6          15
# Bladder                 4          15
# Head and Neck           7          14
# Breast                  3          11
# Lung                    4          10
# Skin                    5          13
# Stomach                 1           8

# %% [markdown]
# ## The Mean of Averages

# %%
resumeTables[sp][dim]['Original'].mean()
# Out:
# 9.714285714285714

# %%
means={}
for sp in ['CHR','DNA','PCD']:
    original=round(resumeTables[sp][1].drop(sp)['Original'].mean(),2)      
    random=round(resumeTables[sp][1].drop(sp)['Random Mean'].mean(),2)    
    driver=round(resumeTables[sp][1].drop(sp)['Driver'].mean(),2)
    
    pRandom = round(random/original*100)
    pDriver = round(driver/original*100)
    means[sp]={}
    means[sp]['Original']=str(original)
    means[sp]['Random']=str(random)+' ('+str(pRandom)+'%)'
    means[sp]['Driver']=str(driver)+' ('+str(pDriver)+'%)'
    
pd.DataFrame(means).T
# Out:
#     Original       Random        Driver
# CHR    16.83  11.88 (71%)  16.83 (100%)
# DNA     14.0  10.65 (76%)    8.33 (60%)
# PCD    22.17  17.26 (78%)   29.0 (131%)

# %%
means={}
for sp in ['CHR','DNA','PCD']:
    original=round(resumeTables[sp][2].drop(sp)['Original'].mean(),2)      
    random=round(resumeTables[sp][2].drop(sp)['Random Mean'].mean(),2)    
    driver=round(resumeTables[sp][2].drop(sp)['Driver'].mean(),2)
    
    pRandom = round(random/original*100)
    pDriver = round(driver/original*100)
    means[sp]={}
    means[sp]['Original']=str(original)
    means[sp]['Random']=str(random)+' ('+str(pRandom)+'%)'
    means[sp]['Driver']=str(driver)+' ('+str(pDriver)+'%)'
    
pd.DataFrame(means).T
# Out:
#     Original      Random     Driver
# CHR      2.0   0.8 (40%)   0.0 (0%)
# DNA      5.0  3.85 (77%)  1.5 (30%)
# PCD      9.5   7.9 (83%)   0.0 (0%)

# %% [markdown]
# ## Number of Cycles and Tetrahedron - Cancer vs Randoms
# To calculate the PH on random networks, we create sub-networks from each SuperPathways, considering the average number of nodes present on the cancer networks from the same super pathways.

# %%
def randomWalkUniqueSetOfNodes(startNode,setLen):
    uniqueSet=set()
    actualNode=startNode
    uniqueSet.add(actualNode)

    while len(uniqueSet) <setLen:
        n=list(G.neighbors(actualNode))
        actualNode=np.random.choice(n)
        uniqueSet.add(actualNode)

    return uniqueSet

def getNumberOfCircles(G):
    dm=pd.DataFrame(dict(nx.shortest_path_length(G))).sort_index()
    dm=dm[sorted(dm.columns)]
    skeleton = gd.RipsComplex(distance_matrix = dm.values) 

    Rips_simplex_tree = skeleton.create_simplex_tree(max_dimension = 2)
    BarCode = Rips_simplex_tree.persistence() 

    return len([bd for bd in BarCode if (bd[0]==1)])

def getNumberOfTetrahedron(G):
    dm=pd.DataFrame(dict(nx.shortest_path_length(G))).sort_index()
    dm=dm[sorted(dm.columns)]
    skeleton = gd.RipsComplex(distance_matrix = dm.values) 

    Rips_simplex_tree = skeleton.create_simplex_tree(max_dimension = 3)
    BarCode = Rips_simplex_tree.persistence() 

    return len([bd for bd in BarCode if (bd[0]==2)])

# %%
# %%time
networks={}
networksRandom={}
resumeCancer={}
resumeRandom={}
for sp in ['CHR','DNA','PCD']:
    resumeCancer[sp]={}
    resumeRandom[sp]={}
    
    #Original SP
    G = pathwaysWrapper.pathwaysNames[names[sp]].networkLCC
    print(sp,'nodes',len(G.nodes))
    
    #######DATA FROM CANCER NETWORKS######## 
    totalCircle=resumeTables[sp][1].drop(sp)['Original'].sum()
    totalTetra=resumeTables[sp][2].drop(sp)['Original'].sum()
    #The average number of nodes found in the 6 cancer network from to actual SP
    avgNodes=int(round(resumeTables[sp][0].drop(sp)['Original'].mean(),0) )
    print('avgNodes totalCircle totalTetra:',avgNodes,totalCircle,totalTetra)
    
    resumeCancer[sp]['Total Circles']=totalCircle
    resumeCancer[sp]['Circles Mean']=round(resumeTables[sp][1].drop(sp)['Original'].mean(),2)
    resumeCancer[sp]['Circles STD']=round(resumeTables[sp][1].drop(sp)['Original'].std(),2)
    resumeCancer[sp]['Total Tetra']=totalTetra
    resumeCancer[sp]['Tetra Mean']=round(resumeTables[sp][2].drop(sp)['Original'].mean(),2)
    resumeCancer[sp]['Tetra STD']=round(resumeTables[sp][2].drop(sp)['Original'].std(),2)
    
    #######DATA FROM RANDOM NETWORKS######## 
    #get the hub:
    hub=(max(dict(G.degree).items(),key=lambda x:x[1]))[0]
    networksRandom[sp]={}
    networksRandom[sp]['Circles']=[]
    networksRandom[sp]['Tetra']=[]
    print('Random Networks:')
    for i in range(30):
        randSet=randomWalkUniqueSetOfNodes(hub,avgNodes)
        G_rand = nx.subgraph(G,randSet)
        print(nx.info(G_rand))
        networksRandom[sp][i+1]=G_rand
        networksRandom[sp]['Circles'].append(getNumberOfCircles(G_rand))
        networksRandom[sp]['Tetra'].append(getNumberOfTetrahedron(G_rand))
        
    print('Circles:',networksRandom[sp]['Circles'])
    print('Circles Total:',sum(networksRandom[sp]['Circles']))
    print('Tetra:',networksRandom[sp]['Tetra'])
    print('Tetra Total:',sum(networksRandom[sp]['Tetra']))
    
    resumeRandom[sp]['Total Circles']=sum(networksRandom[sp]['Circles'])
    resumeRandom[sp]['Circles Mean']=round(np.mean(networksRandom[sp]['Circles']),2)
    resumeRandom[sp]['Circles STD']=round(np.std(networksRandom[sp]['Circles']),2)
    
    resumeRandom[sp]['Total Tetra']=sum(networksRandom[sp]['Tetra'])
    resumeRandom[sp]['Tetra Mean']=round(np.mean(networksRandom[sp]['Tetra']),2)
    resumeRandom[sp]['Tetra STD']=round(np.std(networksRandom[sp]['Tetra']),2)
        
    print('\n')
# Out:
# CHR nodes 221
# avgNodes totalCircle totalTetra: 161 101 12
# Random Networks:
# Graph named 'Pathway Network' with 161 nodes and 1813 edges
# Graph named 'Pathway Network' with 161 nodes and 1796 edges
# Graph named 'Pathway Network' with 161 nodes and 1939 edges
# Graph named 'Pathway Network' with 161 nodes and 1901 edges
# Graph named 'Pathway Network' with 161 nodes and 1936 edges
# Graph named 'Pathway Network' with 161 nodes and 1822 edges
# Graph named 'Pathway Network' with 161 nodes and 1888 edges
# Graph named 'Pathway Network' with 161 nodes and 1842 edges
# Graph named 'Pathway Network' with 161 nodes and 1863 edges
# Graph named 'Pathway Network' with 161 nodes and 1891 edges
# Graph named 'Pathway Network' with 161 nodes and 1896 edges
# Graph named 'Pathway Network' with 161 nodes and 1922 edges
# Graph named 'Pathway Network' with 161 nodes and 1885 edges
# Graph named 'Pathway Network' with 161 nodes and 1853 edges
# Graph named 'Pathway Network' with 161 nodes and 1897 edges
# Graph named 'Pathway Network' with 161 nodes and 1892 edges
# Graph named 'Pathway Network' with 161 nodes and 1748 edges
# Graph named 'Pathway Network' with 161 nodes and 1908 edges
# Graph named 'Pathway Network' with 161 nodes and 1799 edges
# Graph named 'Pathway Network' with 161 nodes and 1906 edges
# Graph named 'Pathway Network' with 161 nodes and 1794 edges
# Graph named 'Pathway Network' with 161 nodes and 1865 edges
# Graph named 'Pathway Network' with 161 nodes and 1892 edges
# Graph named 'Pathway Network' with 161 nodes and 1816 edges
# Graph named 'Pathway Network' with 161 nodes and 1826 edges
# Graph named 'Pathway Network' with 161 nodes and 1810 edges
# Graph named 'Pathway Network' with 161 nodes and 1823 edges
# Graph named 'Pathway Network' with 161 nodes and 1867 edges
# Graph named 'Pathway Network' with 161 nodes and 1833 edges
# Graph named 'Pathway Network' with 161 nodes and 1880 edges
# Circles: [6, 10, 6, 6, 9, 7, 5, 7, 5, 9, 8, 2, 9, 8, 8, 4, 10, 7, 7, 5, 10, 6, 5, 6, 7, 12, 8, 5, 7, 3]
# Circles Total: 207
# Tetra: [3, 4, 3, 4, 4, 4, 3, 3, 3, 3, 3, 3, 4, 3, 3, 4, 2, 4, 4, 4, 4, 4, 4, 4, 4, 3, 3, 3, 4, 4]
# Tetra Total: 105
#
#
# DNA nodes 300
# avgNodes totalCircle totalTetra: 224 84 30
# Random Networks:
# Graph named 'Pathway Network' with 224 nodes and 5831 edges
# Graph named 'Pathway Network' with 224 nodes and 6062 edges
# Graph named 'Pathway Network' with 224 nodes and 5720 edges
# Graph named 'Pathway Network' with 224 nodes and 5524 edges
# Graph named 'Pathway Network' with 224 nodes and 5933 edges
# Graph named 'Pathway Network' with 224 nodes and 5897 edges
# Graph named 'Pathway Network' with 224 nodes and 5852 edges
# Graph named 'Pathway Network' with 224 nodes and 5560 edges
# Graph named 'Pathway Network' with 224 nodes and 5741 edges
# Graph named 'Pathway Network' with 224 nodes and 5675 edges
# Graph named 'Pathway Network' with 224 nodes and 5614 edges
# Graph named 'Pathway Network' with 224 nodes and 5932 edges
# Graph named 'Pathway Network' with 224 nodes and 5778 edges
# Graph named 'Pathway Network' with 224 nodes and 5661 edges
# Graph named 'Pathway Network' with 224 nodes and 5348 edges
# Graph named 'Pathway Network' with 224 nodes and 5926 edges
# Graph named 'Pathway Network' with 224 nodes and 5717 edges
# Graph named 'Pathway Network' with 224 nodes and 5964 edges
# Graph named 'Pathway Network' with 224 nodes and 5760 edges
# Graph named 'Pathway Network' with 224 nodes and 5531 edges
# Graph named 'Pathway Network' with 224 nodes and 5610 edges
# Graph named 'Pathway Network' with 224 nodes and 5694 edges
# Graph named 'Pathway Network' with 224 nodes and 6037 edges
# Graph named 'Pathway Network' with 224 nodes and 5868 edges
# Graph named 'Pathway Network' with 224 nodes and 5815 edges
# Graph named 'Pathway Network' with 224 nodes and 6046 edges
# Graph named 'Pathway Network' with 224 nodes and 5806 edges
# Graph named 'Pathway Network' with 224 nodes and 5905 edges
# Graph named 'Pathway Network' with 224 nodes and 5860 edges
# Graph named 'Pathway Network' with 224 nodes and 5585 edges
# Circles: [3, 3, 6, 7, 4, 5, 4, 2, 7, 3, 5, 5, 4, 5, 5, 3, 5, 5, 3, 3, 3, 6, 4, 4, 8, 4, 5, 3, 6, 2]
# Circles Total: 132
# Tetra: [3, 5, 3, 4, 5, 5, 3, 5, 4, 2, 4, 3, 3, 6, 7, 4, 4, 5, 3, 3, 3, 4, 5, 4, 2, 4, 4, 5, 4, 4]
# Tetra Total: 120
#
#
# PCD nodes 206
# avgNodes totalCircle totalTetra: 158 133 57
# Random Networks:
# Graph named 'Pathway Network' with 158 nodes and 2395 edges
# Graph named 'Pathway Network' with 158 nodes and 2385 edges
# Graph named 'Pathway Network' with 158 nodes and 2433 edges
# Graph named 'Pathway Network' with 158 nodes and 2412 edges
# Graph named 'Pathway Network' with 158 nodes and 2446 edges
# Graph named 'Pathway Network' with 158 nodes and 2442 edges
# Graph named 'Pathway Network' with 158 nodes and 2403 edges
# Graph named 'Pathway Network' with 158 nodes and 2427 edges
# Graph named 'Pathway Network' with 158 nodes and 2407 edges
# Graph named 'Pathway Network' with 158 nodes and 2413 edges
# Graph named 'Pathway Network' with 158 nodes and 2391 edges
# Graph named 'Pathway Network' with 158 nodes and 2405 edges
# Graph named 'Pathway Network' with 158 nodes and 2438 edges
# Graph named 'Pathway Network' with 158 nodes and 2433 edges
# Graph named 'Pathway Network' with 158 nodes and 2434 edges
# Graph named 'Pathway Network' with 158 nodes and 2442 edges
# Graph named 'Pathway Network' with 158 nodes and 2424 edges
# Graph named 'Pathway Network' with 158 nodes and 2449 edges
# Graph named 'Pathway Network' with 158 nodes and 2451 edges
# Graph named 'Pathway Network' with 158 nodes and 2431 edges
# Graph named 'Pathway Network' with 158 nodes and 2428 edges
# Graph named 'Pathway Network' with 158 nodes and 2431 edges
# Graph named 'Pathway Network' with 158 nodes and 2289 edges
# Graph named 'Pathway Network' with 158 nodes and 2441 edges
# Graph named 'Pathway Network' with 158 nodes and 2357 edges
# Graph named 'Pathway Network' with 158 nodes and 2429 edges
# Graph named 'Pathway Network' with 158 nodes and 2470 edges
# Graph named 'Pathway Network' with 158 nodes and 2424 edges
# Graph named 'Pathway Network' with 158 nodes and 2448 edges
# Graph named 'Pathway Network' with 158 nodes and 2432 edges
# Circles: [15, 14, 16, 13, 15, 13, 20, 18, 14, 18, 15, 13, 20, 12, 13, 13, 14, 12, 16, 16, 16, 16, 17, 19, 17, 19, 14, 16, 13, 15]
# Circles Total: 462
# Tetra: [7, 11, 10, 10, 10, 11, 8, 8, 10, 10, 8, 11, 9, 10, 9, 9, 6, 9, 8, 10, 6, 11, 6, 10, 7, 11, 11, 7, 9, 10]
# Tetra Total: 272
#
#
# CPU times: total: 2h 32min 1s
# Wall time: 2h 32min 1s

# %%
pd.DataFrame(resumeRandom).T
# Out:
#      Total Circles  Circles Mean  Circles STD  Total Tetra  Tetra Mean  \
# CHR          207.0           6.9         2.18        105.0        3.50
# DNA          132.0           4.4         1.47        120.0        4.00
# PCD          462.0          15.4         2.27        272.0        9.07
#
#      Tetra STD
# CHR       0.56
# DNA       1.10
# PCD       1.59

# %%
pd.DataFrame(resumeCancer).T
# Out:
#      Total Circles  Circles Mean  Circles STD  Total Tetra  Tetra Mean  \
# CHR          101.0         16.83         2.86         12.0         2.0
# DNA           84.0         14.00         2.76         30.0         5.0
# PCD          133.0         22.17         4.40         57.0         9.5
#
#      Tetra STD
# CHR       0.89
# DNA       2.10
# PCD       2.26

# %%
# open a file, where you ant to store the data
file = open('randomWalkNetworks.pickle', 'wb')

# dump information to that file
pickle.dump(networksRandom, file)

# close the file
file.close()
